# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
 # Create a bar chart based upon the above data
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis 
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"])
# Out:
# ([<matplotlib.axis.XTick at 0x7fddda6572b0>,
#   <matplotlib.axis.XTick at 0x7fddda657280>,
#   <matplotlib.axis.XTick at 0x7fddda5c7550>,
#   <matplotlib.axis.XTick at 0x7fddde624550>,
#   <matplotlib.axis.XTick at 0x7fddde624ca0>],
#  [Text(0, 0, 'New Orleans'),
#   Text(1, 0, 'Milwaukee'),
#   Text(2, 0, 'Omaha'),
#   Text(3, 0, 'Pittsburgh'),
#   Text(4, 0, 'Toledo')])

# %%
# Set the limits of the x axis 
plt.xlim(1, len(x_axis))
# Out:
# (1.0, 5.0)

# %%
# Set the limits of the y axis 
plt.ylim(0, max(bars_in_cities)+2)
# Out:
# (0.0, 10.6)

# %%
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# <BarContainer object of 5 artists>
